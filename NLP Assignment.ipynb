# %% [markdown]
# ### x)In this assignment find the frequency of words in a webpage. User can use urllib and BeautifulSoup to extract text from webpage.

# %%
from bs4 import BeautifulSoup
import urllib.request
import nltk
nltk.download('punkt')
response = urllib.request.urlopen('http://php.net/')
html = response.read()
raw = BeautifulSoup(html,"html5lib").get_text()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91866\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
words = nltk.word_tokenize(raw)

# removing punctuation (['!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'])
import string
punct = string.punctuation

words = [word for word in words if word not in punct]

# removing single characters
words = [word for word in words if len(word) > 1]

# removing numbers
words = [word for word in words if not word.isnumeric()]


words = [word.lower() for word in words]

fdist = nltk.FreqDist(words)

for word , freq in fdist.most_common():
    print('{} : {}'.format(word , freq))
# Out:
# the : 259
# php : 159
# of : 94
# release : 94
# for : 91
# this : 70
# in : 64
# is : 60
# be : 52
# and : 51
# can : 51
# found : 51
# to : 49
# please : 46
# version : 45
# downloads : 41
# on : 41
# source : 40
# page : 33
# 8.0.0 : 32
# list : 26
# changes : 26
# team : 25
# visit : 25
# file : 22
# windows : 20
# candidate : 20
# test : 20
# you : 20
# or : 20
# upgrading : 20
# testing : 19
# bug : 18
# development : 17
# availability : 17
# extensions : 16
# released : 16
# all : 16
# not : 16
# an : 15
# other : 15
# announces : 15
# immediate : 15
# our : 15
# binaries : 15
# windows.php.net/download/ : 15
# recorded : 15
# changelog : 15
# users : 15
# beta : 15
# upgrade : 14
# features : 13
# are : 13
# encouraged : 13
# next : 12
# new : 12
# more : 12
# cycle : 12
# security : 11
# reporting : 11
# files : 11
# archive : 11
# system : 11
# download : 11
# 8.0 : 11
# information : 11
# it : 11
# news : 11
# oct : 11
# available : 10
# pleased : 10
# announce : 10
# ...
